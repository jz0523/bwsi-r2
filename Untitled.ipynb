# %%
import numpy as np
import pandas as pd

# %%
air_quality = pd.read_csv('Air_Quality.csv')
air_quality
# Out:
#        Unique ID  Indicator ID                                   Name  \
# 0         179772           640  Boiler Emissions- Total SO2 Emissions
# 1         179785           640  Boiler Emissions- Total SO2 Emissions
# 2         178540           365                Fine particles (PM 2.5)
# 3         178561           365                Fine particles (PM 2.5)
# 4         823217           365                Fine particles (PM 2.5)
# ...          ...           ...                                    ...
# 18020     816914           643          Annual vehicle miles traveled
# 18021     816913           643          Annual vehicle miles traveled
# 18022     816872           643          Annual vehicle miles traveled
# 18023     816832           643          Annual vehicle miles traveled
# 18024     151658           643          Annual vehicle miles traveled
#
#               Measure     Measure Info Geo Type Name  Geo Join ID  \
# ...

# %%
air_quality.sort_values(['Data Value'],ascending = False)
# Out:
#        Unique ID  Indicator ID  \
# 16166     130806           648
# 2864      130807           648
# 6371      130792           648
# 885       131431           648
# 9603      131046           653
# ...          ...           ...
# 9254      179817           641
# 13604     130481           641
# 15810     179770           640
# 13676     130435           640
# 15030     828092           661
#
#                                                    Name  \
# 16166   Asthma emergency department visits due to PM2.5
# 2864    Asthma emergency department visits due to PM2.5
# 6371    Asthma emergency department visits due to PM2.5
# 885     Asthma emergency department visits due to PM2.5
# 9603   Asthma emergency departments visits due to Ozone
# ...                                                 ...
# 9254            Boiler Emissions- Total PM2.5 Emissions
# 13604           Boiler Emissions- Total PM2.5 Emissions
# 15810             Boiler Emissions- Total SO2 Emissions
# ...

# %%
PM2022 = air_quality.loc[(air_quality["Time Period"] == 'Annual Average 2022') & (air_quality['Name'] == 'Fine particles (PM 2.5)')]
PM2022.sort_values(['Data Value'],ascending =False)
# Out:
#        Unique ID  Indicator ID                     Name Measure Measure Info  \
# 1554      823210           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 15798     823345           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 14881     823255           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 16788     823369           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 4832      823249           365  Fine particles (PM 2.5)    Mean       mcg/m3
# ...          ...           ...                      ...     ...          ...
# 2072      823568           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 17731     823577           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 16132     823468           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 2483      823375           365  Fine particles (PM 2.5)    Mean       mcg/m3
# 16191     823456           365  Fine particles (PM 2.5)    Mean       mcg/m3
#
# ...
